# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelEncoder

# %%
appeal_draft = pd.read_csv('appeal_draft.csv')
sjc_draft = pd.read_csv('sjc_draft.csv')

# %%
sjc_draft.shape
# Out:
# (646, 5)

# %%
appeal_draft.shape
# Out:
# (1915, 4)

# %%
appeal_draft.head()
# Out:
#                                                cases  \
# 0  stephanie lallo & anothervs. marcia szabo & an...
# 1  richard l. healer& othersvs. department of env...
# 2         svitlana vorontsova vs. jaroslav waronzov.
# 3  baby furniture warehouse store, inc. vs. meubl...
# 4                      commonwealth vs. david jones.
#
#                                             headnote  \
# 0  practice, civil, summary judgment. real proper...
# 1  massachusetts clean water act. administrative ...
# 2  divorce and separation, foreign judgment. comi...
# 3  contract, construction of contract, choice of ...
# 4  homicide. practice, criminal, instructions to ...
#
#                                                 text      type
# 0  on august 15, 2006, the plaintiffs, stephanie ...     civil
# 1  this case arises from the grant of a groundwat...     civil
# 2  we are asked to decide whether a judge of the ...       NaN
# 3  we deal here with the application and interpre...     civil
# ...

# %%
cases_nan = appeal_draft.loc[appeal_draft['type'].isnull()]

# %%
cases_nan.shape # 266 cases.
# Out:
# (266, 4)

# %%
cases_nan.head()
# Out:
#                                          cases  \
# 2   svitlana vorontsova vs. jaroslav waronzov.
# 31       diane j. halpern vs. michael s. rabb.
# 36      commonwealth vs. vanya v., a juvenile.
# 48       commonwealth vs. richard a. monteiro.
# 53                agnes smithvs. robert jones.
#
#                                              headnote  \
# 2   divorce and separation, foreign judgment. comi...
# 31  contempt. divorce and separation, child suppor...
# 36  constitutional law, search and seizure. search...
# 48  rape. evidence, first complaint.at the trial o...
# 53  abuse prevention. protective order.in proceedi...
#
#                                                  text type
# 2   we are asked to decide whether a judge of the ...  NaN
# 31  diane j. halpern (mother) appeals from a conte...  NaN
# 36  officer gallo of the marblehead police departm...  NaN
# 48  after a jury trial in the superior court, the ...  NaN
# ...

# %%
sjc_draft = pd.read_csv('sjc_draft.csv')

# %%
sjc_draft.type.unique()
# Out:
# array(['criminal', 'civil', nan], dtype=object)

# %%
sjc_draft.shape
# Out:
# (646, 5)

# %%
cases_df = sjc_draft['cases']

# %%
cases_df
# Out:
# 0                   commonwealth  vs.  admilson resende.
# 1                   commonwealth  vs.  george philbrook.
# 2                  linda s. bowers  vs.  p. wile's, inc.
# 3                     commonwealth  vs.  jared abdallah.
# 4                     commonwealth  vs.  robert d. wade.
# 5      marcia d. bellermann & othersvs.  fitchburg ga...
# 6      commonwealth  vs.  marcel a. diggs. commonweal...
# 7                       commonwealth  vs.  danny vargas.
# 8      elaine k. murray & anothervs.  department of c...
# 9      curt f. pfannenstiehl  vs.  diane l. pfannenst...
# 10                         commonwealth  vs.  kim henry.
# 11      frederick clay  vs.  massachusetts parole board.
# 12                    commonwealth  vs.  jahmal brangan.
# 13     suffolk construction company, inc.  vs.  bench...
# 14     the first marblehead corporation & anothervs. ...
# 15          commonwealth  vs.  timothea t. neary-french.
# ...

# %%
cases_df[317]
# Out:
# 'in the matter of e.c.'

# %%
new_sjc_draft = sjc_draft[317:]

# %%
new_sjc_draft.head()
# Out:
#                                                  cases  \
# 317                              in the matter of e.c.
# 318                  commonwealth  vs.  joseph wright.
# 319  brian rafferty  vs.  merck & co., inc., & anot...
# 320              commonwealth  vs.  johnelle m. brown.
# 321                            commonwealth  vs.  g.f.
#
#                                               headnote  \
# 317  sjc-12230incompetent person, commitment.  prac...
# 318  sjc-11950homicide.  constitutional law, admiss...
# 319  sjc-12347negligence, pharmaceutical manufactur...
# 320  sjc-12313assault and battery.  intimidation of...
# 321  amended april 13, 2018. amended may 11, 2018.s...
#
#                                                   text      type     caseid
# 317  in this appeal, we consider whether the dismis...  criminal  sjc-12230
# 318  the defendant, joseph wright, appeals from two...  criminal  sjc-11950
# ...

# %%
new_sjc_draft
# Out:
#                                                  cases  \
# 317                              in the matter of e.c.
# 318                  commonwealth  vs.  joseph wright.
# 319  brian rafferty  vs.  merck & co., inc., & anot...
# 320              commonwealth  vs.  johnelle m. brown.
# 321                            commonwealth  vs.  g.f.
# 322            commonwealth  vs.  michael c. grundman.
# 323  luis s. spencer  vs.  civil service commission...
# 324                 commonwealth  vs.  emilia escobar.
# 325  mary alice boelter & othersvs.  board of selec...
# 326                        care and protection of m.c.
# 327  tara dorrianvs.  lvnv funding, llc (and a cons...
# 328                commonwealth  vs.  michael walters.
# 329                           j.h.  vs.  commonwealth.
# 330                 in the matter of ariel j. strauss.
# 331  dental service of massachusetts, inc.  vs.  co...
# 332    exxon mobil corporation  vs.  attorney general.
# ...

# %%
appealed = []
judge = []

# %%
new_sjc_draft['appealed'] = ""
new_sjc_draft['judge'] = ""
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_sjc_draft.head()
# Out:
#                                                  cases  \
# 317                              in the matter of e.c.
# 318                  commonwealth  vs.  joseph wright.
# 319  brian rafferty  vs.  merck & co., inc., & anot...
# 320              commonwealth  vs.  johnelle m. brown.
# 321                            commonwealth  vs.  g.f.
#
#                                               headnote  \
# 317  sjc-12230incompetent person, commitment.  prac...
# 318  sjc-11950homicide.  constitutional law, admiss...
# 319  sjc-12347negligence, pharmaceutical manufactur...
# 320  sjc-12313assault and battery.  intimidation of...
# 321  amended april 13, 2018. amended may 11, 2018.s...
#
#                                                   text      type     caseid  \
# 317  in this appeal, we consider whether the dismis...  criminal  sjc-12230
# 318  the defendant, joseph wright, appeals from two...  criminal  sjc-11950
# ...

# %%
new_sjc_draft['appealed'][317] = 'Yes'
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
new_sjc_draft.at[317, 'appealed'] = 'Yes'

# %%
new_sjc_draft.iloc[297]
# Out:
# cases       takiyah d. white  vs.  chief justice of the bo...
# headnote    sjc-12643supreme judicial court, superintenden...
# text        the petitioner, takiyah d. white, raises alleg...
# type                                                      NaN
# caseid                                              sjc-12643
# appealed                                                   No
# judge
# Name: 614, dtype: object

# %%
new_sjc_draft[['cases','appealed']]
# Out:
#                                                  cases   appealed
# 317                              in the matter of e.c.        Yes
# 318                  commonwealth  vs.  joseph wright.         No
# 319  brian rafferty  vs.  merck & co., inc., & anot...         No
# 320              commonwealth  vs.  johnelle m. brown.         No
# 321                            commonwealth  vs.  g.f.  Partially
# 322            commonwealth  vs.  michael c. grundman.        Yes
# 323  luis s. spencer  vs.  civil service commission...         No
# 324                 commonwealth  vs.  emilia escobar.        Yes
# 325  mary alice boelter & othersvs.  board of selec...
# 326                        care and protection of m.c.
# 327  tara dorrianvs.  lvnv funding, llc (and a cons...
# 328                commonwealth  vs.  michael walters.
# 329                           j.h.  vs.  commonwealth.
# 330                 in the matter of ariel j. strauss.
# ...

# %%
new_sjc_draft.at[645,'appealed'] = 'Partially'

# %%
new_sjc_draft
# Out:
#                                                  cases  \
# 317                              in the matter of e.c.
# 318                  commonwealth  vs.  joseph wright.
# 319  brian rafferty  vs.  merck & co., inc., & anot...
# 320              commonwealth  vs.  johnelle m. brown.
# 321                            commonwealth  vs.  g.f.
# 322            commonwealth  vs.  michael c. grundman.
# 323  luis s. spencer  vs.  civil service commission...
# 324                 commonwealth  vs.  emilia escobar.
# 325  mary alice boelter & othersvs.  board of selec...
# 326                        care and protection of m.c.
# 327  tara dorrianvs.  lvnv funding, llc (and a cons...
# 328                commonwealth  vs.  michael walters.
# 329                           j.h.  vs.  commonwealth.
# 330                 in the matter of ariel j. strauss.
# 331  dental service of massachusetts, inc.  vs.  co...
# 332    exxon mobil corporation  vs.  attorney general.
# ...
